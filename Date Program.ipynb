# %% [markdown]
# <a href="https://colab.research.google.com/github/BrazilCheerer/My_repository_320/blob/main/Slicer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while(True):
  aDate = (input("Enter a date (MM/DD/YYYY): "))



  month = (aDate[:2])
  day = (aDate[3:5])
  year = (aDate[6:])

  try:
    if(int(month) > 12 or int(month) < 0 or int(day) > 31 or int(day) < 0):
      print("Invalid format! Try again")
      continue
  except:
    print("Invalid format! Try again")
    continue




  print(f"Month: {month}, day: {day}, year: {year}")
  break
# Out:
# Enter a date (MM/DD/YYYY): sdfsdfsdf
# Invalid format! Try again
# Enter a date (MM/DD/YYYY): sdfsdfsdfdsfsdf
# Invalid format! Try again
# Enter a date (MM/DD/YYYY): sdfsdfsdfsdfsdfsdf
# Invalid format! Try again
# Enter a date (MM/DD/YYYY): dsdfsdcsdf
# Invalid format! Try again
# Enter a date (MM/DD/YYYY): sdfsdfsdfsdfs
# Invalid format! Try again
# Enter a date (MM/DD/YYYY): dfgdsfdfgdf
# Invalid format! Try again
